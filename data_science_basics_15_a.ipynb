# %% [markdown]
# <img src="http://hilpisch.com/tpq_logo.png" alt="The Python Quants" width="35%" align="right" border="0"><br>

# %% [markdown]
# # Data Science Basics

# %% [markdown]
# &copy; Dr. Yves J. Hilpisch | The Python Quants GmbH
#
# https://tpq.io | [training@tpq.io](mailto:trainin@tpq.io) | [@dyjh](http://x.com/dyjh)

# %% [markdown]
# ## `mplfinance` package

# %% [markdown]
# ## Imports

# %%
# !git clone https://github.com/tpq-classes/data_science_basics.git
import sys
sys.path.append('data_science_basics')

# %% [markdown]
# ## Installation

# %% [markdown]
# Install the financial plotting package `mplfinance`, based on `matplotlib`, as follows:
#
#     pip install mplfinance
#
# See https://github.com/matplotlib/mplfinance.

# %%
pip install mplfinance

# %%
import pandas as pd
import warnings as w
import mplfinance as fplt
w.simplefilter('ignore')
# %config InlineBackend.figure_format = 'svg'

# %% [markdown]
# ## OHLC Bars

# %%
# url = 'https://certificate.tpq.io/nvda_ohlc.csv'  # data including stock splits

# %%
# url = 'https://certificate.tpq.io/aapl_ohlc.csv'  # data including stock splits

# %%
# data = pd.read_csv(url, index_col=0, parse_dates=True)

# %%
url = 'https://certificate.tpq.io/aapldata.csv'
data = pd.read_csv(url, index_col=0, parse_dates=True)[
    ['OPEN', 'HIGH', 'LOW', 'CLOSE', 'VOLUME']]
data.columns = ['Open', 'High', 'Low', 'Close', 'Volume']

# %%
data.info()

# %%
data['Close'].plot()

# %% [markdown]
# ### Default

# %%
fplt.plot(data.iloc[-50:])

# %%
fplt.plot(data.iloc[-50:], style='charles')

# %% [markdown]
# ## Candlesticks

# %%
fplt.plot(data.iloc[-50:], type='candle', style='charles')

# %%
fplt.plot(data.iloc[-50:], type='candle', style='charles', volume=True)

# %%
fplt.plot(data.iloc[-50:], type='candle', style='charles', mav=(5, 10, 15))

# %%
fplt.plot(data.iloc[-100:], type='candle', style='charles', mav=(10, 20),
          show_nontrading=True)

# %%
fplt.plot(data.iloc[-100:], type='candle', style='charles', mav=(10, 20),
          show_nontrading=True, volume=True)

# %% [markdown]
# ### Renko Charts

# %% [markdown]
# For Renko charts see https://www.investopedia.com/terms/r/renkochart.asp.

# %%
fplt.plot(data.iloc[-250:], type='renko', style='charles')

# %%
fplt.plot(data.iloc[-175:], type='renko', style='charles',
         mav=(10, 20))

# %% [markdown]
# ### Point-and-Figure

# %% [markdown]
# For Point-and-Figure (P&F) charts see https://www.investopedia.com/terms/p/pointandfigurechart.asp.

# %%
fplt.plot(data.iloc[-350:], type='pnf', style='charles')

# %% [markdown]
# <img src="http://hilpisch.com/tpq_logo.png" alt="The Python Quants" width="35%" align="right" border="0"><br>
#
# <a href="https://tpq.io" target="_blank">http://tpq.io</a> | <a href="mailto:training@tpq.io">training@tpq.io</a> | <a href="http://twitter.com/dyjh" target="_blank">@dyjh</a>
